# %%
import pandas as pd

# %%
import pycaret

# %%
prakinsons_data = pd.read_csv('parkinsons.csv')

# %%
prakinsons_data.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426
# 1   0.00465   0.00696     0.01394       0.06134             0.626
# 2   0.00544   0.00781     0.01633       0.05233             0.482
# 3   0.00502   0.00698     0.01505       0.05492             0.517
# 4   0.00655   0.00908     0.01966       0.06425             0.584
#
#    Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA      NHR     HNR  status  \
# ...

# %%
from pycaret.classification import *

# %%
prakinsons_data.drop(['name'], axis=1,inplace=True)

# %%
classify_experiment = setup(prakinsons_data,
                           target='status',
                           log_experiment=True,
                           session_id=123,
                           experiment_name='prakinsons_disease')
# Out:
# <style type="text/css">
# #T_1ab48_row19_col1, #T_1ab48_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1ab48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ab48_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1ab48_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ab48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ab48_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1ab48_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1ab48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ab48_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1ab48_row1_col1" class="data row1 col1" >status</td>
#     </tr>
#     <tr>
#       <th id="T_1ab48_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_5bae2 th {
#   text-align: left;
# }
# ...
