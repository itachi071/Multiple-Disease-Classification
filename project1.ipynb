# %%
import pandas as pd

# %%
import pycaret

# %%
diabetes_data = pd.read_csv('diabetes.csv')

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from pycaret.classification import *

# %%
classify_experiment = setup(diabetes_data,
                           target='Outcome',
                           log_experiment=True,
                           session_id=123,
                           experiment_name='diabetes_disease')
# Out:
# <style type="text/css">
# #T_8cc03_row19_col1, #T_8cc03_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8cc03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cc03_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8cc03_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cc03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8cc03_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_8cc03_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8cc03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8cc03_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8cc03_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_8cc03_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
## comparing differnet models
compare_models()
# Out:
# <style type="text/css">
# #T_4a21d th {
#   text-align: left;
# }
# ...

# %%
logistic=create_model('lr')
# Out:
# <style type="text/css">
# #T_28e6c_row10_col0, #T_28e6c_row10_col1, #T_28e6c_row10_col2, #T_28e6c_row10_col3, #T_28e6c_row10_col4, #T_28e6c_row10_col5, #T_28e6c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_28e6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28e6c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_28e6c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_28e6c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_28e6c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_28e6c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_28e6c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_28e6c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
model=tune_model(logistic)
# Out:
# <style type="text/css">
# #T_2ee8b_row10_col0, #T_2ee8b_row10_col1, #T_2ee8b_row10_col2, #T_2ee8b_row10_col3, #T_2ee8b_row10_col4, #T_2ee8b_row10_col5, #T_2ee8b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2ee8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ee8b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2ee8b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2ee8b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2ee8b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2ee8b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2ee8b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2ee8b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
model
# Out:
# LogisticRegression(C=7.863, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
